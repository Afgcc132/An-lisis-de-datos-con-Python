# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Premier_League_23_24.csv')

# %%
df.head(5)
# Out:
#    round_number     league_name                                  name  \
# 0             1  Premier League            Burnley vs Manchester City
# 1             1  Premier League          Arsenal vs Nottingham Forest
# 2             1  Premier League    AFC Bournemouth vs West Ham United
# 3             1  Premier League  Brighton & Hove Albion vs Luton Town
# 4             1  Premier League                     Everton vs Fulham
#
#   starting_at          home_team_name     away_team_name  home_team_goals  \
# 0   8/11/2023                 Burnley    Manchester City                0
# 1   8/12/2023                 Arsenal  Nottingham Forest                2
# 2   8/12/2023         AFC Bournemouth    West Ham United                1
# 3   8/12/2023  Brighton & Hove Albion         Luton Town                4
# 4   8/12/2023                 Everton             Fulham                0
#
#    away_team_goals
# 0                3
# 1                1
# 2                1
# ...

# %%
df.tail(5)
# Out:
#      round_number     league_name                                   name  \
# 375            38  Premier League          Crystal Palace vs Aston Villa
# 376            38  Premier League   Liverpool vs Wolverhampton Wanderers
# 377            38  Premier League                   Luton Town vs Fulham
# 378            38  Premier League     Manchester City vs West Ham United
# 379            38  Premier League  Sheffield United vs Tottenham Hotspur
#
#     starting_at    home_team_name           away_team_name  home_team_goals  \
# 375   5/19/2024    Crystal Palace              Aston Villa                5
# 376   5/19/2024         Liverpool  Wolverhampton Wanderers                2
# 377   5/19/2024        Luton Town                   Fulham                2
# 378   5/19/2024   Manchester City          West Ham United                3
# 379   5/19/2024  Sheffield United        Tottenham Hotspur                0
#
#      away_team_goals
# 375                0
# 376                0
# ...

# %%
df.describe()
# Out:
#        round_number  home_team_goals  away_team_goals
# count    380.000000       380.000000       380.000000
# mean      19.500000         1.800000         1.478947
# std       10.980313         1.365616         1.277811
# min        1.000000         0.000000         0.000000
# 25%       10.000000         1.000000         1.000000
# 50%       19.500000         2.000000         1.000000
# 75%       29.000000         3.000000         2.000000
# max       38.000000         6.000000         8.000000

# %%
df.isnull().sum()
# Out:
# round_number       0
# league_name        0
# name               0
# starting_at        0
# home_team_name     0
# away_team_name     0
# home_team_goals    0
# away_team_goals    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   round_number     380 non-null    int64
#  1   league_name      380 non-null    object
#  2   name             380 non-null    object
#  3   starting_at      380 non-null    object
#  4   home_team_name   380 non-null    object
#  5   away_team_name   380 non-null    object
#  6   home_team_goals  380 non-null    int64
#  7   away_team_goals  380 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 23.9+ KB

# %%
df.columns
# Out:
# Index(['round_number', 'league_name', 'name', 'starting_at', 'home_team_name',
#        'away_team_name', 'home_team_goals', 'away_team_goals'],
#       dtype='object')

# %%
# Restablecer el índice a un índice numérico desde 0
df = df.reset_index()
df.head(5)
# Out:
#    index  round_number     league_name                                  name  \
# 0      0             1  Premier League            Burnley vs Manchester City
# 1      1             1  Premier League          Arsenal vs Nottingham Forest
# 2      2             1  Premier League    AFC Bournemouth vs West Ham United
# 3      3             1  Premier League  Brighton & Hove Albion vs Luton Town
# 4      4             1  Premier League                     Everton vs Fulham
#
#   starting_at          home_team_name     away_team_name  home_team_goals  \
# 0   8/11/2023                 Burnley    Manchester City                0
# 1   8/12/2023                 Arsenal  Nottingham Forest                2
# 2   8/12/2023         AFC Bournemouth    West Ham United                1
# 3   8/12/2023  Brighton & Hove Albion         Luton Town                4
# 4   8/12/2023                 Everton             Fulham                0
#
#    away_team_goals
# 0                3
# ...

# %%
df['Total_Goals'] = df['home_team_goals']+df['away_team_goals']

# %%
df.head(5)
# Out:
#    index  round_number     league_name                                  name  \
# 0      0             1  Premier League            Burnley vs Manchester City
# 1      1             1  Premier League          Arsenal vs Nottingham Forest
# 2      2             1  Premier League    AFC Bournemouth vs West Ham United
# 3      3             1  Premier League  Brighton & Hove Albion vs Luton Town
# 4      4             1  Premier League                     Everton vs Fulham
#
#   starting_at          home_team_name     away_team_name  home_team_goals  \
# 0   8/11/2023                 Burnley    Manchester City                0
# 1   8/12/2023                 Arsenal  Nottingham Forest                2
# 2   8/12/2023         AFC Bournemouth    West Ham United                1
# 3   8/12/2023  Brighton & Hove Albion         Luton Town                4
# 4   8/12/2023                 Everton             Fulham                0
#
#    away_team_goals  Total_Goals
# ...

# %%
df.describe()
# Out:
#             index  round_number  home_team_goals  away_team_goals  Total_Goals
# count  380.000000    380.000000       380.000000       380.000000   380.000000
# mean   189.500000     19.500000         1.800000         1.478947     3.278947
# std    109.840794     10.980313         1.365616         1.277811     1.656865
# min      0.000000      1.000000         0.000000         0.000000     0.000000
# 25%     94.750000     10.000000         1.000000         1.000000     2.000000
# 50%    189.500000     19.500000         2.000000         1.000000     3.000000
# 75%    284.250000     29.000000         3.000000         2.000000     4.000000
# max    379.000000     38.000000         6.000000         8.000000     8.000000

# %%
Cero = df[df['Total_Goals'] == 0]

# %%
print(Cero)
# Out:
#      index  round_number     league_name  \
# 46      46             5  Premier League
# 49      49             6  Premier League
# 75      75             8  Premier League
# 168    168            17  Premier League
# 197    197            20  Premier League
# 201    201            21  Premier League
# 207    207            21  Premier League
# 209    209            22  Premier League
# 292    292            30  Premier League
# 299    299            31  Premier League
# 349    349            36  Premier League
#
#                                                   name starting_at  \
# 46                          AFC Bournemouth vs Chelsea   9/17/2023
# 49                            Crystal Palace vs Fulham   9/23/2023
# 75                 Crystal Palace vs Nottingham Forest   10/7/2023
# 168                     Liverpool vs Manchester United  12/17/2023
# 197          West Ham United vs Brighton & Hove Albion    1/2/2024
# ...

# %%
Porcentaje = (len(Cero)/len(df))*100
print(f'El porcentja de partidos que terminaron sin goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron sin goles es : 2.8947368421052633

# %%
Un_Gol = df[df['Total_Goals'] == 1]
Porcentaje = (len(Un_Gol)/len(df))*100
print(f'El porcentja de partidos que terminaron con un gol es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con un gol es : 11.052631578947368

# %%
Dos_Goles = df[df['Total_Goals'] == 2]
Porcentaje = (len(Dos_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con dos goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con dos goles es : 21.31578947368421

# %%
Tres_Goles = df[df['Total_Goals'] == 3]
Porcentaje = (len(Tres_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con tres goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con tres goles es : 21.052631578947366

# %%
cuatro_Goles = df[df['Total_Goals'] == 4]
Porcentaje = (len(cuatro_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con cuatro goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con cuatro goles es : 21.052631578947366

# %%
cinco_Goles  = df[df['Total_Goals'] == 5]
Porcentaje = (len(cinco_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con cinco goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con cinco goles es : 13.157894736842104

# %%
seis_Goles  = df[df['Total_Goals'] == 6]
Porcentaje = (len(seis_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con seis goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con seis goles es : 6.052631578947368

# %%
siete_Goles  = df[df['Total_Goals'] == 7]
Porcentaje = (len(siete_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con siete goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con siete goles es : 2.631578947368421

# %%
ocho_Goles  = df[df['Total_Goals'] == 8]
Porcentaje = (len(ocho_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con ocho goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con ocho goles es : 0.7894736842105263

# %%
nueve_Goles  = df[df['Total_Goals'] == 9]
Porcentaje = (len(nueve_Goles)/len(df))*100
print(f'El porcentja de partidos que terminaron con nueve goles es : {Porcentaje}')
# Out:
# El porcentja de partidos que terminaron con nueve goles es : 0.0

# %%
df.head(5)
# Out:
#    index  round_number     league_name                                  name  \
# 0      0             1  Premier League            Burnley vs Manchester City
# 1      1             1  Premier League          Arsenal vs Nottingham Forest
# 2      2             1  Premier League    AFC Bournemouth vs West Ham United
# 3      3             1  Premier League  Brighton & Hove Albion vs Luton Town
# 4      4             1  Premier League                     Everton vs Fulham
#
#   starting_at          home_team_name     away_team_name  home_team_goals  \
# 0   8/11/2023                 Burnley    Manchester City                0
# 1   8/12/2023                 Arsenal  Nottingham Forest                2
# 2   8/12/2023         AFC Bournemouth    West Ham United                1
# 3   8/12/2023  Brighton & Hove Albion         Luton Town                4
# 4   8/12/2023                 Everton             Fulham                0
#
#    away_team_goals  Total_Goals
# ...

# %%
winner = []

for index, row in df.iterrows():
    if row['home_team_goals'] > row['away_team_goals']:
        winner.append(row['home_team_name'])
    elif row['home_team_goals'] < row['away_team_goals']:
        winner.append(row['away_team_name'])
    else:
        winner.append('Draw')

# %%
if len(winner) == len(df):
  print("Tienen la misma longitud")
else:
  print('No tienen la misma longitud')
# Out:
# Tienen la misma longitud

# %%
df['winner'] = winner

# %%
df.head(5)
# Out:
#    index  round_number     league_name                                  name  \
# 0      0             1  Premier League            Burnley vs Manchester City
# 1      1             1  Premier League          Arsenal vs Nottingham Forest
# 2      2             1  Premier League    AFC Bournemouth vs West Ham United
# 3      3             1  Premier League  Brighton & Hove Albion vs Luton Town
# 4      4             1  Premier League                     Everton vs Fulham
#
#   starting_at          home_team_name     away_team_name  home_team_goals  \
# 0   8/11/2023                 Burnley    Manchester City                0
# 1   8/12/2023                 Arsenal  Nottingham Forest                2
# 2   8/12/2023         AFC Bournemouth    West Ham United                1
# 3   8/12/2023  Brighton & Hove Albion         Luton Town                4
# 4   8/12/2023                 Everton             Fulham                0
#
#    away_team_goals  Total_Goals                  winner
# ...

# %%
team_stats_list = []

for index, row in df.iterrows():
    if row['winner'] == row['home_team_name']:
        team_stats_list.append({'team_name': row['home_team_name'], 'wins': 1, 'draws': 0, 'losses': 0, 'points': 3})
        team_stats_list.append({'team_name': row['away_team_name'], 'wins': 0, 'draws': 0, 'losses': 1, 'points': 0})
    elif row['winner'] == row['away_team_name']:
        team_stats_list.append({'team_name': row['home_team_name'], 'wins': 0, 'draws': 0, 'losses': 1, 'points': 0})
        team_stats_list.append({'team_name': row['away_team_name'], 'wins': 1, 'draws': 0, 'losses': 0, 'points': 3})
    elif row['winner'] == 'Draw':
        team_stats_list.append({'team_name': row['home_team_name'], 'wins': 0, 'draws': 1, 'losses': 0, 'points': 1})
        team_stats_list.append({'team_name': row['away_team_name'], 'wins': 0, 'draws': 1, 'losses': 0, 'points': 1})

# Convert the list to a DataFrame
team_stats_df = pd.DataFrame(team_stats_list)

# Group by team name and sum up the wins, draws, losses, and points
team_stats = team_stats_df.groupby('team_name').sum().reset_index()

# Sort the DataFrame by points, wins, and then by draws
team_stats = team_stats.sort_values(by=['points', 'wins', 'draws'], ascending=False).reset_index(drop=True)

# Display the final DataFrame
print(team_stats)
# Out:
#                   team_name  wins  draws  losses  points
# 0           Manchester City    28      7       3      91
# 1                   Arsenal    28      5       5      89
# 2                 Liverpool    24     10       4      82
# 3               Aston Villa    20      8      10      68
# 4         Tottenham Hotspur    20      6      12      66
# 5                   Chelsea    18      9      11      63
# 6         Manchester United    18      6      14      60
# 7          Newcastle United    18      6      14      60
# 8           West Ham United    14     10      14      52
# 9            Crystal Palace    13     10      15      49
# 10          AFC Bournemouth    13      9      16      48
# 11                  Everton    13      9      16      48
# 12   Brighton & Hove Albion    12     12      14      48
# 13                   Fulham    13      8      17      47
# 14  Wolverhampton Wanderers    13      7      18      46
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='team_name', y='points', data=team_stats)
plt.xticks(rotation=90)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='team_name', y='wins', data=team_stats)
plt.xticks(rotation=90)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='team_name', y='draws', data=team_stats)
plt.xticks(rotation=90)
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>
