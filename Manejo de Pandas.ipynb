# %%
import pandas as pd
import numpy as np

# %%
np.random.randint(90,100)
# Out:
# 98

# %%
def random_marks(n, a, b):
  x=[]
  for i in range(n):
    x.append(np.random.randint(a,b))
  return(x)

# %%
random_marks(20,10,90)
# Out:
# [22,
#  24,
#  62,
#  69,
#  39,
#  86,
#  66,
#  29,
#  66,
#  71,
#  57,
#  85,
#  15,
#  38,
#  26,
#  29,
#  59,
#  64,
#  45,
#  55]

# %%
nu = 5
sd = 2.5
df = nu + 2.5 * np.random.randn(1000)
df
# Out:
# array([ 4.69272361e+00,  5.06706274e+00,  6.41673032e+00,  9.52242778e+00,
#         3.54953506e+00,  3.67903139e+00,  6.02540553e+00,  5.04693216e+00,
#         5.17258956e+00,  3.87742365e+00,  7.89074553e+00,  1.07370729e+00,
#         6.16993319e+00,  1.59949269e+00,  7.47391954e+00,  5.86422577e+00,
#         2.13698901e+00,  3.31513267e+00,  3.80772682e+00,  4.27175223e+00,
#         8.73041630e+00,  3.81032268e+00,  8.14156064e+00,  7.41440352e+00,
#         5.61975083e+00,  4.82514898e+00,  6.80400753e+00,  8.44484988e+00,
#         6.91304710e+00,  1.93086581e+00,  1.04002764e+01,  3.80999077e+00,
#         6.73513942e+00,  5.17645307e+00,  4.20756836e+00,  7.42492423e-01,
#         5.32198264e+00,  2.45793255e+00,  5.56025437e+00,  5.98632971e+00,
#         6.24224530e+00,  5.64202193e+00,  2.80996887e+00,  2.15190342e+00,
#        -1.26895098e+00,  4.22776475e+00,  5.07331859e+00,  9.99010010e+00,
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df)
# Out:
# (array([  6.,  25.,  50., 140., 230., 268., 166.,  77.,  29.,   9.]),
#  array([-2.93300607, -1.40255376,  0.12789855,  1.65835086,  3.18880316,
#          4.71925547,  6.24970778,  7.78016009,  9.3106124 , 10.8410647 ,
#         12.37151701]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
import numpy as np

# Crear un dummy dataframe con datos de ventas
dummy_df = pd.DataFrame({
    'Product': ['A', 'B', 'C', 'D'] * 25,
    'Sales': np.random.randint(100, 1000, 100),
    'Date': pd.date_range(start='2023-01-01', periods=100, freq='D')
})

print(dummy_df.head())
# Out:
#   Product  Sales       Date
# 0       A    890 2023-01-01
# 1       B    198 2023-01-02
# 2       C    770 2023-01-03
# 3       D    316 2023-01-04
# 4       A    282 2023-01-05

# %%
dummy_df.describe()
# Out:
#            Sales                 Date
# count  100.00000                  100
# mean   553.19000  2023-02-19 12:00:00
# min    103.00000  2023-01-01 00:00:00
# 25%    315.75000  2023-01-25 18:00:00
# 50%    568.50000  2023-02-19 12:00:00
# 75%    787.75000  2023-03-16 06:00:00
# max    994.00000  2023-04-10 00:00:00
# std    263.17923                  NaN

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_Group = df.groupby(['sex','smoker'])
df_Group.size()
# Out:
# sex     smoker
# Female  No        54
#         Yes       33
# Male    No        97
#         Yes       60
# dtype: int64

# %%
df_Group['total_bill'].describe()
# Out:
#                count       mean       std   min      25%    50%      75%  \
# sex    smoker
# Female No       54.0  18.105185  7.286455  7.25  12.6500  16.69  20.8625
#        Yes      33.0  17.977879  9.189751  3.07  12.7600  16.27  22.1200
# Male   No       97.0  19.791237  8.726566  7.51  13.8100  18.24  22.8200
#        Yes      60.0  22.284500  9.911845  7.25  15.2725  20.39  28.5725
#
#                  max
# sex    smoker
# Female No      35.83
#        Yes     44.30
# Male   No      48.33
#        Yes     50.81

# %%
df_numeric = df.select_dtypes(include=np.number)
df_numeric.head()
# Out:
#    total_bill   tip  size
# 0       16.99  1.01     2
# 1       10.34  1.66     3
# 2       21.01  3.50     3
# 3       23.68  3.31     2
# 4       24.59  3.61     4

# %%
df_numeric.aggregate(['mean','median','std','min','max'])
# Out:
#         total_bill        tip      size
# mean     19.785943   2.998279  2.569672
# median   17.795000   2.900000  2.000000
# std       8.902412   1.383638  0.951100
# min       3.070000   1.000000  1.000000
# max      50.810000  10.000000  6.000000

# %%
df_Group.head(1)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 56       38.01  3.00    Male    Yes  Sat  Dinner     4
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1

# %%
df_Group.tail(1)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df_sorted = df.sort_values(by='tip', ascending=False)
df_sorted.head()
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3
# 212       48.33   9.00  Male     No   Sat  Dinner     4
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 59        48.27   6.73  Male     No   Sat  Dinner     4
# 141       34.30   6.70  Male     No  Thur   Lunch     6

# %%
df_sex = df_sorted.groupby('smoker')
df_sex.head()
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4

# %%
df_sex = df_sorted.groupby('sex')
df_sex.head()
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4

# %% [markdown]
# ## Conjunto de entrenamiento y testing

# %%
# Correct raw file URL
url = 'https://raw.githubusercontent.com/Afgcc132/python-ml-course/master/datasets/customer-churn-model/Customer%20Churn%20Model.txt'

# Reading the data into a DataFrame
df = pd.read_csv(url)

# %%
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
len(df)
# Out:
# 3333

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df, test_size=0.2)

# %%
train.shape
# Out:
# (2666, 21)
